# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Student Stress Factors.csv")

# %%
df
# Out:
#               Timestamp  Kindly Rate your Sleep Quality 😴  \
# 0   27/10/2023 21:54:15                                 3
# 1   28/10/2023 12:24:40                                 4
# 2   28/10/2023 12:24:51                                 2
# 3   28/10/2023 12:26:11                                 3
# 4   28/10/2023 12:26:45                                 2
# 5   28/10/2023 12:31:02                                 3
# 6   28/10/2023 12:34:45                                 3
# 7   28/10/2023 12:35:43                                 4
# 8   28/10/2023 12:36:07                                 2
# 9   28/10/2023 12:36:20                                 1
# 10  28/10/2023 12:37:22                                 2
# 11  28/10/2023 12:38:40                                 3
# 12  28/10/2023 12:39:43                                 2
# 13  28/10/2023 12:40:50                                 4
# 14  28/10/2023 12:41:12                                 4
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                           0
# Kindly Rate your Sleep Quality 😴                                    0
# How many times a week do you suffer headaches 🤕?                    0
# How would you rate you academic performance 👩‍🎓?                    0
# how would you rate your study load?                                 0
# How many times a week you practice extracurricular activities 🎾?    0
# How would you rate your stress levels?                              0
# dtype: int64

# %%
df.head()
# Out:
#              Timestamp  Kindly Rate your Sleep Quality 😴  \
# 0  27/10/2023 21:54:15                                 3
# 1  28/10/2023 12:24:40                                 4
# 2  28/10/2023 12:24:51                                 2
# 3  28/10/2023 12:26:11                                 3
# 4  28/10/2023 12:26:45                                 2
#
#    How many times a week do you suffer headaches 🤕?  \
# 0                                                 1
# 1                                                 1
# 2                                                 1
# 3                                                 2
# 4                                                 3
#
#    How would you rate you academic performance 👩‍🎓?  \
# 0                                                 3
# 1                                                 2
# 2                                                 2
# 3                                                 3
# ...

# %%
df.tail()
# Out:
#               Timestamp  Kindly Rate your Sleep Quality 😴  \
# 48  28/10/2023 23:45:09                                 3
# 49  29/10/2023 00:32:26                                 1
# 50  29/10/2023 11:40:20                                 5
# 51  31/10/2023 10:10:03                                 1
# 52  31/10/2023 20:49:11                                 3
#
#     How many times a week do you suffer headaches 🤕?  \
# 48                                                 3
# 49                                                 1
# 50                                                 1
# 51                                                 1
# 52                                                 2
#
#     How would you rate you academic performance 👩‍🎓?  \
# 48                                                 4
# 49                                                 1
# 50                                                 5
# 51                                                 5
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Kindly Rate your Sleep Quality 😴',
#        'How many times a week do you suffer headaches 🤕?',
#        'How would you rate you academic performance 👩‍🎓?',
#        'how would you rate your study load?',
#        'How many times a week you practice extracurricular activities 🎾?',
#        'How would you rate your stress levels?'],
#       dtype='object')

# %%
df.shape
# Out:
# (53, 7)

# %%
type[df]
# Out:
# type[              Timestamp  Kindly Rate your Sleep Quality 😴  \
# 0   27/10/2023 21:54:15                                 3
# 1   28/10/2023 12:24:40                                 4
# 2   28/10/2023 12:24:51                                 2
# 3   28/10/2023 12:26:11                                 3
# 4   28/10/2023 12:26:45                                 2
# 5   28/10/2023 12:31:02                                 3
# 6   28/10/2023 12:34:45                                 3
# 7   28/10/2023 12:35:43                                 4
# 8   28/10/2023 12:36:07                                 2
# 9   28/10/2023 12:36:20                                 1
# 10  28/10/2023 12:37:22                                 2
# 11  28/10/2023 12:38:40                                 3
# 12  28/10/2023 12:39:43                                 2
# 13  28/10/2023 12:40:50                                 4
# 14  28/10/2023 12:41:12                                 4
# ...

# %%
df.loc[0]
# Out:
# Timestamp                                                           27/10/2023 21:54:15
# Kindly Rate your Sleep Quality 😴                                                      3
# How many times a week do you suffer headaches 🤕?                                      1
# How would you rate you academic performance 👩‍🎓?                                      3
# how would you rate your study load?                                                   4
# How many times a week you practice extracurricular activities 🎾?                      2
# How would you rate your stress levels?                                                3
# Name: 0, dtype: object

# %%
x=df.iloc[:,:-1]

# %%
y=df.iloc[:,:3]

# %%
x
# Out:
#               Timestamp  Kindly Rate your Sleep Quality 😴  \
# 0   27/10/2023 21:54:15                                 3
# 1   28/10/2023 12:24:40                                 4
# 2   28/10/2023 12:24:51                                 2
# 3   28/10/2023 12:26:11                                 3
# 4   28/10/2023 12:26:45                                 2
# 5   28/10/2023 12:31:02                                 3
# 6   28/10/2023 12:34:45                                 3
# 7   28/10/2023 12:35:43                                 4
# 8   28/10/2023 12:36:07                                 2
# 9   28/10/2023 12:36:20                                 1
# 10  28/10/2023 12:37:22                                 2
# 11  28/10/2023 12:38:40                                 3
# 12  28/10/2023 12:39:43                                 2
# 13  28/10/2023 12:40:50                                 4
# 14  28/10/2023 12:41:12                                 4
# ...

# %%
y
# Out:
#               Timestamp  Kindly Rate your Sleep Quality 😴  \
# 0   27/10/2023 21:54:15                                 3
# 1   28/10/2023 12:24:40                                 4
# 2   28/10/2023 12:24:51                                 2
# 3   28/10/2023 12:26:11                                 3
# 4   28/10/2023 12:26:45                                 2
# 5   28/10/2023 12:31:02                                 3
# 6   28/10/2023 12:34:45                                 3
# 7   28/10/2023 12:35:43                                 4
# 8   28/10/2023 12:36:07                                 2
# 9   28/10/2023 12:36:20                                 1
# 10  28/10/2023 12:37:22                                 2
# 11  28/10/2023 12:38:40                                 3
# 12  28/10/2023 12:39:43                                 2
# 13  28/10/2023 12:40:50                                 4
# 14  28/10/2023 12:41:12                                 4
# ...
